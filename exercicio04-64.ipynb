# %% [markdown]
# # Definição do problema

# %% [markdown]
# - Criar um modelo para previsão do preço das casas

# %% [markdown]
# # Etapa 01: Importação das bibliotecas

# %%
# %tensorflow_version 2.x
import tensorflow as tf
tf.__version__
# Out:
# '2.5.0'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Etapa 02: Importação dos dados

# %%
house_data = pd.read_csv('/kc-house-data.csv', encoding="ISO-8859-1")

# %%
# Visualizar os 10 primeiros registros
house_data.head(10)
# Out:
#            id             date      price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000   221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000   538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000   180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000   604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000   510000.0  ... -122.045           1800        7503
# 5  7237550310  20140512T000000  1225000.0  ... -122.005           4760      101930
# 6  1321400060  20140627T000000   257500.0  ... -122.327           2238        6819
# 7  2008000270  20150115T000000   291850.0  ... -122.315           1650        9711
# 8  2414600126  20150415T000000   229500.0  ... -122.337           1780        8113
# 9  3793500160  20150312T000000   323000.0  ... -122.031           2390        7570
#
# [10 rows x 21 columns]

# %%
# Visualizar os 10 últimos registros
house_data.tail(10)
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 21603  7852140040  20140825T000000  ...           2270        5731
# 21604  9834201367  20150126T000000  ...           1400        1230
# 21605  3448900210  20141014T000000  ...           2520        6023
# 21606  7936000429  20150326T000000  ...           2050        6200
# 21607  2997800021  20150219T000000  ...           1330        1265
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [10 rows x 21 columns]

# %%
# Resumo dos registros da tabela
house_data.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  2.161300e+04  ...   21613.000000   21613.000000
# mean   4.580302e+09  5.400881e+05  ...    1986.552492   12768.455652
# std    2.876566e+09  3.671272e+05  ...     685.391304   27304.179631
# min    1.000102e+06  7.500000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.219500e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %%
# Informações da tabela
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# # Etapa 03: Limpeza da base de dados

# %%
# Verifica se há dados nulos
sns.heatmap(house_data.isnull());

# %%
# Remove coluna "id" e "date" que não vai colaborar para o modelo
#house_data = house_data.drop(labels=["id", "date"], axis=1)

# Remove colunas "id", "zipcode", "lat", "long" e "date"
house_data = house_data.drop(labels=["id", "zipcode", "lat", "long", "date"], axis=1)

house_data.head()
# Out:
#       price  bedrooms  bathrooms  ...  yr_renovated  sqft_living15  sqft_lot15
# 0  221900.0         3       1.00  ...             0           1340        5650
# 1  538000.0         3       2.25  ...          1991           1690        7639
# 2  180000.0         2       1.00  ...             0           2720        8062
# 3  604000.0         4       3.00  ...             0           1360        5000
# 4  510000.0         3       2.00  ...             0           1800        7503
#
# [5 rows x 16 columns]

# %% [markdown]
# # Etapa 04: Visualização da base de dados

# %%
# Apresenta de forma visual a relação entre as colunas
sns.pairplot(house_data);
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Separa as variáveis numéricas da(s) variável(is) categórica(s)
x_numerical = house_data.drop(labels=["waterfront"], axis=1)

# Apenas para avaliar a correlação com menos variáveis
x_numerical1 = house_data.drop(labels=["waterfront", "bedrooms", "bathrooms", "sqft_living", "sqft_lot", "floors", "view", "condition"], axis=1)
x_numerical2 = house_data.drop(labels=["grade", "sqft_above", "sqft_basement", "yr_built", "yr_renovated", "sqft_living15", "sqft_lot15"], axis=1)

x_numerical.head()
# Out:
#       price  bedrooms  bathrooms  ...  yr_renovated  sqft_living15  sqft_lot15
# 0  221900.0         3       1.00  ...             0           1340        5650
# 1  538000.0         3       2.25  ...          1991           1690        7639
# 2  180000.0         2       1.00  ...             0           2720        8062
# 3  604000.0         4       3.00  ...             0           1360        5000
# 4  510000.0         3       2.00  ...             0           1800        7503
#
# [5 rows x 15 columns]

# %%
# Avalia a correlação 1ª parte
sns.heatmap(x_numerical1.corr(), annot=True);

# %%
# Avalia a correlação 2ª parte
sns.heatmap(x_numerical2.corr(), annot=True);

# %% [markdown]
# # Etapa 05: Tratamento da base de dados

# %%
# Remove variáveis não tão significantes
x_numerical = x_numerical.drop(labels=["yr_built", "sqft_lot15", "sqft_lot", "condition"], axis=1)

# %%
# Separa variável categórica
x_cat = house_data[['waterfront']]
x_cat.head()
# Out:
#    waterfront
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
# Concatena os valores numéricos e categóricos já tratados
x_all = pd.concat([x_cat, x_numerical], axis=1)
x_all.head()
# Out:
#    waterfront     price  bedrooms  ...  sqft_basement  yr_renovated  sqft_living15
# 0           0  221900.0         3  ...              0             0           1340
# 1           0  538000.0         3  ...            400          1991           1690
# 2           0  180000.0         2  ...              0             0           2720
# 3           0  604000.0         4  ...            910             0           1360
# 4           0  510000.0         3  ...              0             0           1800
#
# [5 rows x 12 columns]

# %%
# Define nossas variáveis x e variável y
x = x_all.drop(labels=["price"], axis=1)
y = x_all[["price"]]

# %%
x.head()
# Out:
#    waterfront  bedrooms  bathrooms  ...  sqft_basement  yr_renovated  sqft_living15
# 0           0         3       1.00  ...              0             0           1340
# 1           0         3       2.25  ...            400          1991           1690
# 2           0         2       1.00  ...              0             0           2720
# 3           0         4       3.00  ...            910             0           1360
# 4           0         3       2.00  ...              0             0           1800
#
# [5 rows x 11 columns]

# %%
y.head()
# Out:
#       price
# 0  221900.0
# 1  538000.0
# 2  180000.0
# 3  604000.0
# 4  510000.0

# %%
# Normaliza valores para que fiquem entre 0 e 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(x)
y = scaler.fit_transform(y)
x = pd.DataFrame(x)
y = pd.DataFrame(y)

# %% [markdown]
# # Etapa 06: Configurar base de treinamento

# %%
x.head()
# Out:
#     0         1        2         3   ...        7         8         9         10
# 0  0.0  0.090909  0.12500  0.067170  ...  0.097588  0.000000  0.000000  0.161934
# 1  0.0  0.090909  0.28125  0.172075  ...  0.206140  0.082988  0.988089  0.222165
# 2  0.0  0.060606  0.12500  0.036226  ...  0.052632  0.000000  0.000000  0.399415
# 3  0.0  0.121212  0.37500  0.126038  ...  0.083333  0.188797  0.000000  0.165376
# 4  0.0  0.090909  0.25000  0.104906  ...  0.152412  0.000000  0.000000  0.241094
#
# [5 rows x 11 columns]

# %%
y.head()
# Out:
#           0
# 0  0.019266
# 1  0.060721
# 2  0.013770
# 3  0.069377
# 4  0.057049

# %%
x.shape
# Out:
# (21613, 11)

# %%
y.shape
# Out:
# (21613, 1)

# %% [markdown]
# # Etapa 07: Configuração da base de treinamento, validação e teste

# %%
# Divide nossos dados para formação da base de treinamento e teste
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25) # 85% base de treinamento e 25% base de teste

# %%
x_train.shape
# Out:
# (16209, 11)

# %%
x_test.shape
# Out:
# (5404, 11)

# %%
y_train.shape
# Out:
# (16209, 1)

# %%
y_test.shape
# Out:
# (5404, 1)

# %% [markdown]
# # Etapa 08: Construção e treinamento do modelo

# %%
# Constroi o modelo, utilizando 100 neuronios e mais camadas de aprendizado
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=100, activation='relu', input_shape = [11]))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=100, activation='relu'))
model.add(tf.keras.layers.Dense(units=1, activation='linear'))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 100)               1200
# _________________________________________________________________
# dense_26 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_27 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 21,501
# Trainable params: 21,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compila o modelo, utilizando uma função de otimização e uma medida de perda
model.compile(optimizer='Adam', loss="mean_squared_error")

# %%
# Configura o modo de treinamento
epochs_hist = model.fit(x_train, y_train, epochs=25, batch_size=100, validation_split=0.25)
# Out:
# Epoch 1/25
# 122/122 [==============================] - 1s 7ms/step - loss: 0.0012 - val_loss: 8.1861e-04
# Epoch 2/25
# 122/122 [==============================] - 0s 3ms/step - loss: 8.8202e-04 - val_loss: 9.8547e-04
# Epoch 3/25
# 122/122 [==============================] - 0s 3ms/step - loss: 8.5464e-04 - val_loss: 8.5841e-04
# Epoch 4/25
# 122/122 [==============================] - 0s 3ms/step - loss: 8.2383e-04 - val_loss: 7.5614e-04
# Epoch 5/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.9419e-04 - val_loss: 8.2342e-04
# Epoch 6/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.8639e-04 - val_loss: 7.7046e-04
# Epoch 7/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.6378e-04 - val_loss: 0.0012
# Epoch 8/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.8311e-04 - val_loss: 8.3891e-04
# Epoch 9/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.6311e-04 - val_loss: 7.7077e-04
# Epoch 10/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.3912e-04 - val_loss: 7.9434e-04
# Epoch 11/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.3649e-04 - val_loss: 7.8161e-04
# Epoch 12/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.6216e-04 - val_loss: 8.3273e-04
# Epoch 13/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.3280e-04 - val_loss: 7.2729e-04
# Epoch 14/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.1912e-04 - val_loss: 7.6934e-04
# Epoch 15/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.2260e-04 - val_loss: 7.6853e-04
# Epoch 16/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.0141e-04 - val_loss: 7.1072e-04
# Epoch 17/25
# 122/122 [==============================] - 0s 3ms/step - loss: 7.0264e-04 - val_loss: 7.8843e-04
# Epoch 18/25
# 122/122 [==============================] - 0s 3ms/step - loss: 6.9311e-04 - val_loss: 7.4335e-04
# Epoch 19/25
# 122/122 [==============================] - 0s 3ms/step - loss: 6.8938e-04 - val_loss: 8.1587e-04
# Epoch 20/25
# 122/122 [==============================] - 0s 3ms/step - loss: 6.9827e-04 - val_loss: 7.3376e-04
# Epoch 21/25
# 122/122 [==============================] - 0s 3ms/step - loss: 6.9417e-04 - val_loss: 7.9281e-04
# Epoch 22/25
# 122/122 [==============================] - 0s 3ms/step - loss: 6.8854e-04 - val_loss: 7.5854e-04
# Epoch 23/25
# 122/122 [==============================] - 0s 3ms/step - loss: 6.9199e-04 - val_loss: 7.5571e-04
# Epoch 24/25
# 122/122 [==============================] - 0s 3ms/step - loss: 6.7837e-04 - val_loss: 7.4346e-04
# Epoch 25/25
# 122/122 [==============================] - 0s 3ms/step - loss: 6.6381e-04 - val_loss: 8.0327e-04

# %% [markdown]
# # Etapa 09: Avaliação do modelo

# %%
# Variáveis de perda
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
# Apresenta o gráfico mostrando o progresso da perda durante o treinamento
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and validation loss')
# Out:
# Text(0, 0.5, 'Training and validation loss')

# %%
y_predict = model.predict(x_test)
y_predict
# Out:
# array([[0.03258906],
#        [0.05182346],
#        [0.05836523],
#        ...,
#        [0.03582245],
#        [0.04031648],
#        [0.09621103]], dtype=float32)

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color="r")
plt.title('Prediction')
plt.xlabel('Model prediction')
plt.ylabel('True values');

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

# %%
k = x_test.shape[1]
k
# Out:
# 11

# %%
n = len(x_test)
n
# Out:
# 5404

# %%
# Valor 0 = previsões perfeitas
mae = mean_absolute_error(y_test_orig, y_predict_orig)
mae
# Out:
# 143542.9416433429

# %%
# Penaliza os outliers, quanto maior os outliers, maior será o erro
mse = mean_squared_error(y_test_orig, y_predict_orig)
mse
# Out:
# 45821209263.32343

# %%
# Prevê estimativa de quanto os resíduos estão dispersos
rmse = sqrt(mse)
rmse
# Out:
# 214058.89204451058

# %%
# Indica a qualidade do modelo (melhor quanto mais próximo de 1)
# Bons modelos chegam acima de 0.95
r2 = r2_score(y_test_orig, y_predict_orig)
r2
# Out:
# 0.6484679365910644

# %%
# Caso o r2 ajustado seja menor que 1 (menor que o r2)
# é porque provavelmente há variáveis insignificantes
r2_ajustado = 1 - (1 - r2) * (n - 1) / (n - k - 1)
r2_ajustado
# Out:
# 0.6477507903192732

# %%
print(
    'MAE        : ', mae, 
    '\nMSE        : ', mse, 
    '\nRMSE       : ', rmse, 
    '\nR2         : ', r2, 
    '\nR2 Ajustado: ', r2_ajustado
)
# Out:
# MAE        :  143542.9416433429
# MSE        :  45821209263.32343
# RMSE       :  214058.89204451058
# R2         :  0.6484679365910644
# R2 Ajustado:  0.6477507903192732
